# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings ('ignore')

# %%
case = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

case.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
case.shape
# Out:
# (30, 17)

# %%
case.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
case.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
case.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
case["HR"]
# Out:
# 0     139
# 1     156
# 2     141
# 3     136
# 4     151
# 5     232
# 6     212
# 7     217
# 8     167
# 9     161
# 10    172
# 11    230
# 12    176
# 13    198
# 14    146
# 15    137
# 16    140
# 17    171
# 18    145
# 19    167
# 20    177
# 21    177
# 22    120
# 23    100
# 24    130
# 25    187
# 26    136
# 27    154
# 28    148
# 29    186
# Name: HR, dtype: int64

# %%
case["2B"]
# Out:
# 0     300
# 1     277
# 2     303
# 3     260
# 4     289
# 5     308
# 6     272
# 7     246
# 8     278
# 9     294
# 10    279
# 11    278
# 12    243
# 13    262
# 14    277
# 15    288
# 16    292
# 17    272
# 18    274
# 19    257
# 20    295
# 21    265
# 22    236
# 23    251
# 24    272
# 25    263
# 26    288
# 27    289
# 28    260
# 29    274
# Name: 2B, dtype: int64

# %%
case["H"]
# Out:
# 0     1497
# 1     1349
# 2     1395
# 3     1381
# 4     1515
# 5     1480
# 6     1397
# 7     1370
# 8     1383
# 9     1495
# 10    1419
# 11    1363
# 12    1331
# 13    1379
# 14    1405
# 15    1386
# 16    1462
# 17    1341
# 18    1378
# 19    1382
# 20    1351
# 21    1363
# 22    1420
# 23    1361
# 24    1374
# 25    1346
# 26    1486
# 27    1494
# 28    1324
# 29    1479
# Name: H, dtype: int64

# %%
case["3B"]
# Out:
# 0     42
# 1     44
# 2     29
# 3     27
# 4     49
# 5     17
# 6     19
# 7     20
# 8     32
# 9     33
# 10    32
# 11    26
# 12    21
# 13    22
# 14    46
# 15    39
# 16    27
# 17    30
# 18    34
# 19    27
# 20    17
# 21    13
# 22    40
# 23    18
# 24    37
# 25    26
# 26    39
# 27    48
# 28    36
# 29    49
# Name: 3B, dtype: int64

# %%
case["BB"]
# Out:
# 0     383
# 1     439
# 2     533
# 3     404
# 4     455
# 5     570
# 6     554
# 7     418
# 8     436
# 9     478
# 10    503
# 11    486
# 12    435
# 13    478
# 14    475
# 15    506
# 16    461
# 17    567
# 18    412
# 19    496
# 20    488
# 21    539
# 22    375
# 23    471
# 24    387
# 25    563
# 26    457
# 27    490
# 28    426
# 29    388
# Name: BB, dtype: int64

# %%
case["RA"]
# Out:
# 0     641
# 1     700
# 2     640
# 3     701
# 4     803
# 5     670
# 6     698
# 7     693
# 8     642
# 9     753
# 10    733
# 11    618
# 12    675
# 13    726
# 14    729
# 15    525
# 16    596
# 17    608
# 18    737
# 19    754
# 20    613
# 21    635
# 22    678
# 23    760
# 24    809
# 25    595
# 26    627
# 27    713
# 28    731
# 29    844
# Name: RA, dtype: int64

# %%
case["CG"]
# Out:
# 0      2
# 1      2
# 2     11
# 3      7
# 4      7
# 5      7
# 6      3
# 7      0
# 8      1
# 9      3
# 10     5
# 11     5
# 12     2
# 13     6
# 14     5
# 15     1
# 16     0
# 17     6
# 18     1
# 19     2
# 20     1
# 21     4
# 22     0
# 23     3
# 24     1
# 25     6
# 26     7
# 27     1
# 28     1
# 29     4
# Name: CG, dtype: int64

# %%
case["SHO"]
# Out:
# 0      8
# 1     12
# 2     10
# 3      9
# 4     12
# 5     10
# 6      4
# 7     10
# 8     12
# 9     10
# 10     9
# 11    13
# 12    12
# 13    12
# 14    15
# 15    15
# 16    13
# 17    21
# 18     7
# 19     8
# 20    14
# 21    13
# 22    12
# 23    10
# 24     7
# 25    21
# 26    18
# 27    12
# 28     6
# 29     4
# Name: SHO, dtype: int64

# %%
case["SHO"].unique()
# Out:
# array([ 8, 12, 10,  9,  4, 13, 15, 21,  7, 14, 18,  6], dtype=int64)

# %%
case["RA"].unique()
# Out:
# array([641, 700, 640, 701, 803, 670, 698, 693, 642, 753, 733, 618, 675,
#        726, 729, 525, 596, 608, 737, 754, 613, 635, 678, 760, 809, 595,
#        627, 713, 731, 844], dtype=int64)

# %%
case["RA"].nunique()
# Out:
# 30

# %%
case["E"]
# Out:
# 0      88
# 1      86
# 2      79
# 3     101
# 4      86
# 5      88
# 6      93
# 7      77
# 8      95
# 9      97
# 10    119
# 11     85
# 12     93
# 13     94
# 14    126
# 15     96
# 16    122
# 17    111
# 18    116
# 19     90
# 20     88
# 21     90
# 22     77
# 23     90
# 24    117
# 25     75
# 26     78
# 27     86
# 28     92
# 29     95
# Name: E, dtype: int64

# %%
case["E"].unique()
# Out:
# array([ 88,  86,  79, 101,  93,  77,  95,  97, 119,  85,  94, 126,  96,
#        122, 111, 116,  90, 117,  75,  78,  92], dtype=int64)

# %%
case['E'].nunique()
# Out:
# 21

# %%
case["RA"].mean()
# Out:
# 688.2333333333333

# %%
case["BB"]
# Out:
# 0     383
# 1     439
# 2     533
# 3     404
# 4     455
# 5     570
# 6     554
# 7     418
# 8     436
# 9     478
# 10    503
# 11    486
# 12    435
# 13    478
# 14    475
# 15    506
# 16    461
# 17    567
# 18    412
# 19    496
# 20    488
# 21    539
# 22    375
# 23    471
# 24    387
# 25    563
# 26    457
# 27    490
# 28    426
# 29    388
# Name: BB, dtype: int64

# %%
case["BB"].mean()
# Out:
# 469.1

# %%
case["ERA"]
# Out:
# 0     3.73
# 1     4.07
# 2     3.67
# 3     3.98
# 4     4.64
# 5     3.80
# 6     4.03
# 7     4.05
# 8     3.74
# 9     4.31
# 10    4.24
# 11    3.57
# 12    3.94
# 13    4.16
# 14    4.14
# 15    2.94
# 16    3.21
# 17    3.36
# 18    4.28
# 19    4.33
# 20    3.43
# 21    3.62
# 22    4.02
# 23    4.41
# 24    4.69
# 25    3.44
# 26    3.72
# 27    4.04
# 28    4.09
# 29    5.04
# Name: ERA, dtype: float64

# %%
case["ERA"].mean()
# Out:
# 3.9563333333333337

# %%
case["SHO"]
# Out:
# 0      8
# 1     12
# 2     10
# 3      9
# 4     12
# 5     10
# 6      4
# 7     10
# 8     12
# 9     10
# 10     9
# 11    13
# 12    12
# 13    12
# 14    15
# 15    15
# 16    13
# 17    21
# 18     7
# 19     8
# 20    14
# 21    13
# 22    12
# 23    10
# 24     7
# 25    21
# 26    18
# 27    12
# 28     6
# 29     4
# Name: SHO, dtype: int64

# %%
case.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
case.nunique().to_frame("No.of unique Values")
# Out:
#      No.of unique Values
# W                     24
# R                     28
# AB                    29
# H                     29
# 2B                    22
# 3B                    23
# HR                    27
# BB                    29
# SO                    29
# SB                    27
# RA                    30
# ER                    30
# ERA                   30
# CG                     9
# SHO                   12
# SV                    20
# E                     21

# %%
case["ERA"].value_counts()
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: ERA, dtype: int64

# %%
case['W']
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
case ['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
ax =sns.countplot(x = 'ERA',data = case)
print ( case ['ERA'].value_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18292\274853142.py in <module>
#       1 ax =sns.countplot(x = 'ERA',data = case)
# ----> 2 print ( case ['ERA'].value_count())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
ax=sns.countplot(x = 'W',data = case)
print ( case ['W'].value_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18292\1361232489.py in <module>
#       1 ax=sns.countplot(x = 'W',data = case)
# ----> 2 print ( case ['W'].value_count())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
ax=sns.countplot(x = 'RA',data = case)
print ( case ['RA'].value_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18292\1647240283.py in <module>
#       1 ax=sns.countplot(x = 'RA',data = case)
# ----> 2 print ( case ['RA'].value_count())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
ax=sns.countplot(x = 'CG',data = case)
print ( case ['CG'].value_count())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18292\1033985138.py in <module>
#       1 ax=sns.countplot(x = 'CG',data = case)
# ----> 2 print ( case ['CG'].value_count())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
plt.title("comparison between 2B and 3B")
sns.scatterplot(x ='2B',y ='3B',data = case,hue='W',palette='bright')
plt.show()

# %%
plt.title("comparison between RA and ERA")
sns.scatterplot(x ='RA',y ='ERA',data = case,hue='W',palette='bright')
plt.show()

# %%
case.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
case['R']= np.cbrt(case['R'])

# %%
case.skew()
# Out:
# W      0.047089
# R      0.892970
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.distplot(case['R'],color="m", kde_kws ={"shade":True},hist=False)
plt.show()

# %%
sns.distplot(case['ER'],color="m", kde_kws ={"shade":True},hist=False)
plt.show()

# %%
sns.distplot(case['ERA'],color="m", kde_kws ={"shade":True},hist=False)
plt.show()

# %%
sns.distplot(case['CG'],color="m", kde_kws ={"shade":True},hist=False)
plt.show()

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE = OrdinalEncoder()
for i in case.columns:
    if case[i].dtypes=='object':
        case[i]=OE.fit_transform(case[i].values.reshape(-1,1))
        case

# %%
plt.figure(figsize = (20,15))
sns.heatmap(case.corr(),linewidths=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Blues_r")
plt.yticks(rotation=0);
plt.show()
